# %% [markdown]
# MP3 - Veri Toplama Tasarımı
#
# Yöntem: Örnek veri seti oluşturma
#
# Veri Kaynağı: Araştırma konusu doğrultusunda hazırlanmış hayali bir CSV dosyası (`data_mp3.csv`)
#
# Konu: Sosyal medyayı kontrolsüz kullanan çocukların zararlı içeriklere maruz kalma düzeyi ve bunun psikolojik etkileri
#
# Veri Açıklaması:
# Bu veri seti, 11–17 yaş aralığındaki öğrencilerin sosyal medya kullanım alışkanlıklarını temsil eden örnek verilerdir.
# Verilerde; kullanılan platform, günlük ekran süresi, zararlı içeriklere maruz kalma düzeyi (1–5 arası), ve ruh hali puanı (1–5 arası) gibi değişkenler bulunmaktadır.
#
# Amaç: Bu veri, çocukların sosyal medya kullanım süresi ve maruz kaldıkları zararlı içeriklerin psikolojik durum üzerindeki olası etkilerini gözlemleyebilmek için hazırlanmıştır.

# %%
import pandas as pd


dosya_yolu = 'mp3_data.xlsx' 



try:
    df = pd.read_excel(dosya_yolu)
    print(f"'{dosya_yolu}' dosyası başarıyla okundu.")

    print("\n--- Çekilen Verinin İlk 15 Satırı (df.head(30)) ---")


    display(df.head(15)) 

except FileNotFoundError:
    print(f"HATA: '{dosya_yolu}' bulunamadı. Lütfen dosya adını ve yolunu kontrol edin.")
except Exception as e:
    print(f"Okuma sırasında bir hata oluştu: {e}")
# Out:
# 'mp3_data.xlsx' dosyası başarıyla okundu.
#
# --- Çekilen Verinin İlk 15 Satırı (df.head(30)) ---
#     sıra  yaş      platform  Ekran süresi (saat)  \
# 0      1   12       YouTube                    2
# 1      2   15        TikTok                    6
# 2      3   14     Instagram                    4
# 3      4   13        TikTok                    5
# 4      5   16       YouTube                    3
# 5      6   17     Instagram                    7
# 6      7   11  YouTube Kids                    1
# 7      8   15      Snapchat                    4
# 8      9   13        TikTok                    5
# 9     10   14     Instagram                    3
# 10    11   12       YouTube                    2
# 11    12   16        TikTok                    6
# 12    13   17     Instagram                    5
# 13    14   15       YouTube                    3
# 14    15   13        TikTok                    6
#
#     Maruz kalınan zararlı içerik  Hal değerlendirmesi  \
# ...
